# %%
import numpy as np
from lattice_class import *
from hamiltonian_constructor_class import *
import scipy.linalg
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 150
plt.rcParams["savefig.dpi"] = 150

# %%
N = 6
lattice = SquareLattice(N)
# lattice.plot(True)
lattice.remove_bonds([(N // 2 * N + N//2 + j, (N // 2 - 1) * N + N//2 + j) for j in range(N//2)])
# lattice.plot(True)
lattice.move_sites(range(N**2 // 2), (0.0, 3.0))
# lattice.plot(True)
# lattice.add_sites([(N // 2 + j, N // 2 + i) for i in range(N//2) for j in range(N//2)])
lattice.add_sites([(3, 4), (4, 3.5), (4, 4.5), (5, 3), (5, 4), (5, 5), (6, 3.5), (6, 4.5), (7, 4)])
lattice.canonical_order()
lattice.add_bonds([(15, 21), (21, 30), (16, 19), (24, 31), (19, 22), (18, 20), (22, 24), (24, 26), (26, 32), (17, 18), (19, 18), (22, 20), (22, 25), (26, 25), (20, 23), (25, 23)])


lattice.add_bonds([(21, 19), (21, 24), ])
lattice.move_sites([0, 1, 2, 6, 7, 8, 12, 13, 14], (0.0, -1.5))
lattice.move_sites([27, 28, 29, 33, 34, 35, 39, 40, 41], (0.0, +1.5))
lattice.move_sites([3, 9, 15], (0.0, -1.0))
lattice.move_sites([30, 36, 42], (0.0, +1.0))
lattice.move_sites([4, 10, 16], (0.0, -0.5))
lattice.move_sites([31, 37, 43], (0.0, +0.5))
lattice.plot(True)
