# %%
import numpy as np
from lattice_class import *

# %%
N = 10
M = 10
a1 = (1.0, 0.0)
a2 = (0.0, 1.0)
lattice = BravaisLattice(a1, a2, N, M)
lattice.plot(True)

# %%
lattice.remove_site(0)
lattice.plot(True)
print(lattice._edges)
# Out:
# Edge between 0 and 1 removed
# Edge between 0 and 10 removed
# ...
