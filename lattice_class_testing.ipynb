# %%
import numpy as np
from lattice_class import *
from hamiltonian_constructor_class import *

plt.rcParams["figure.dpi"] = 150
plt.rcParams["savefig.dpi"] = 150

# %%
lattice = SquareLattice(5)

lattice.plot(True)

lattice.remove_sites([5, 3, 4])
lattice.remove_edges([(0, 1), (14, 13)])

lattice.plot(True)

lattice.add_edges([(0, 1), (14, 13)], [(1, 3), (3, 1)])

# lattice = HoneycombLattice(11, 5)
lattice.plot(True)

# %%
print(lattice.get_local_edge_indices())
# Out:
# [[1], [1, 2, 3], [3, 2], [0, 1, 2], [0, 3, 1, 2], [3, 1, 2], [2, 3], [1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 2, 3], [0, 1, 2], [0, 3, 2, 1], [0, 1, 2, 3], [0, 3, 1, 2], [0, 2, 3], [0, 1], [0, 3, 1], [0, 3, 1], [0, 3, 1], [0, 3]]
