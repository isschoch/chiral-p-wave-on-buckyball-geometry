# %%
import numpy as np
from lattice_class import *

# %%
N = 5
M = 5
a1 = (1.0, 0.0)
a2 = (0.0, 1.0)
lattice = BravaisLattice(a1, a2, N, M, "open")
lattice.plot(True)

# %%
lattice.remove_site(0)
lattice.plot(True)
print(lattice._edges)
print(lattice.get_local_edge_indices())
# Out:
# [[1, 5], [0, 2, 6], [1, 3, 7], [8, 2], [5, 9], [0, 4, 6, 10], [1, 5, 7, 11], [2, 6, 8, 12], [3, 13, 7], [4, 10, 14], [5, 9, 11, 15], [6, 10, 12, 16], [7, 11, 13, 17], [8, 18, 12], [9, 15, 19], [10, 14, 16, 20], [11, 15, 17, 21], [12, 16, 18, 22], [13, 23, 17], [14, 20], [15, 19, 21], [16, 20, 22], [17, 21, 23], [18, 22]]
# [[1, 2], [3, 1, 2], [3, 1, 2], [2, 3], [1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 2, 3], [0, 1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 2, 3], [0, 1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 3, 1, 2], [0, 2, 3], [0, 1], [0, 3, 1], [0, 3, 1], [0, 3, 1], [0, 3]]

# %%
lattice.get_local_edge_index(0, 6)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/2t/mhdwcpp15ps_2ts_kq4nc4_40000gn/T/ipykernel_5740/3339182646.py in <module>
# ----> 1 lattice.get_local_edge_index(0, 6)
#
# ~/Programs/chiral_p_sc_buckyball/chiral-p-wave-on-buckyball-geometry/lattice_class.py in get_local_edge_index(self, site_idx, neighbour_idx)
#     135
#     136     def get_local_edge_index(self, site_idx, neighbour_idx):
# --> 137         assert neighbour_idx in self._edges[site_idx], "Site {} and {} are not adjacent".format(site_idx, neighbour_idx)
#     138         return self._local_edge_idx[site_idx][
#     139             self._edges[site_idx].index(neighbour_idx)
#
# AssertionError: Site 0 and 6 are not adjacent

# %%
lattice.change_local_edge_index((0, 2), 2)
lattice.get_local_edge_index(0, 1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/2t/mhdwcpp15ps_2ts_kq4nc4_40000gn/T/ipykernel_5740/852770819.py in <module>
# ----> 1 lattice.change_local_edge_index((0, 2), 2)
#       2 lattice.get_local_edge_index(0,1)
#
# ~/Programs/chiral_p_sc_buckyball/chiral-p-wave-on-buckyball-geometry/lattice_class.py in change_local_edge_index(self, sites, new_local_idx)
#     141
#     142     def change_local_edge_index(self, sites, new_local_idx):
# --> 143         assert (sites[1] in self._edges[sites[0]]) and (sites[0] in self._edges[sites[1]]), "Site {} and {} are not adjacent".format(sites[0], sites[1])
#     144         self._local_edge_idx[sites[0]][self._edges[sites[0]].index(sites[1])] = new_local_idx
#     145
#
# AssertionError: Site 0 and 2 are not adjacent

# %%
lattice.get_local_edge_index(1, 0)
# Out:
# 3
