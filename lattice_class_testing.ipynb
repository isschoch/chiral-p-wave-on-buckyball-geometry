# %%
import numpy as np
from lattice_class import *

# %%
N = 5
a1 = (1.3, 0.0)
a2 = (1.5, 0.5)
lattice = BravaisLattice(a1, a2, N, N)
lattice.plot(True)

# %%
sites = lattice.get_sites()
rec_sites = lattice.get_reciprocal_sites()
lattice._sites = rec_sites
lattice.plot()

# %%
lattice2 = ChainLatticeAlt(N)
lattice2.plot(True)
lattice2._sites = lattice2.get_reciprocal_sites()
lattice2.plot(True)
