# %%
import numpy as np
from lattice_class import *
from hamiltonian_constructor_class import *

plt.rcParams["figure.dpi"] = 150
plt.rcParams["savefig.dpi"] = 150

# %%
# a1 = (1.0, 0.0)
# a2 = (1.0/2.0, np.sqrt(3.0) / 2.0)
# b = (0.0, -0.5)

lattice = HoneycombLattice(11, 5)
lattice.plot(True)
